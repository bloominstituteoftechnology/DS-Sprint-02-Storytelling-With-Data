# %% [markdown]
# <a href="https://colab.research.google.com/github/invegat/DS-Sprint-02-Storytelling-With-Data/blob/master/LS_DS_123_Make_explanatory_visualizations_LESSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Choose appropriate visualizations
#
#
# Recreate this [example by FiveThirtyEight:](https://fivethirtyeight.com/features/al-gores-new-movie-exposes-the-big-flaw-in-online-movie-ratings/)

# %%
from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
import skimage
import matplotlib.pyplot as plt
from skimage import io

io.imshow(io.imread(url), alpha=1)
io.show();
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
# import urllib3
# import matplotlib.pyplot as plt

# http = urllib3.PoolManager()
# response = http.request('GET', url)
# f = urllib3.util.url.parse_url(url)
# # # create a file-like object from the url
# # f = urllib3.open(url)
# # a = response.data
# # type(a)
# # # read the image file in a numpy array
# # a = plt.imread(f)
# plt.imshow(f,alpha=0.1)
# plt.show()

# %% [markdown]
# Using this data:
#
# https://github.com/fivethirtyeight/data/tree/master/inconvenient-sequel
#
# ### Stretch goals
#
# Recreate more examples from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
# For example:
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/) ([`altair`](https://altair-viz.github.io/gallery/index.html#maps))
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/) ([`statsmodels`](https://www.statsmodels.org/stable/index.html))

# %%
display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/inconvenient-sequel/ratings.csv')

# %%
df.shape
# Out:
# (80053, 27)

# %%
width, height = df.shape
width * height
# Out:
# 2161431

# %%
df.head()
# Out:
#                     timestamp  respondents        category  \
# 0  2017-07-17 12:28:32.785639          402           Males
# 1  2017-07-17 12:28:33.025600           78         Females
# 2  2017-07-17 12:28:33.273919            4   Aged under 18
# 3  2017-07-17 12:28:33.495325            4  Males under 18
# 4  2017-07-17 12:28:33.722849          130      Aged 18-29
#
#                                                 link  average  mean  median  \
# 0   http://www.imdb.com/title/tt6322922/ratings-male      4.6   5.0       2
# 1  http://www.imdb.com/title/tt6322922/ratings-fe...      6.9   7.7      10
# 2  http://www.imdb.com/title/tt6322922/ratings-age_1      4.2   4.2       3
# 3  http://www.imdb.com/title/tt6322922/ratings-ma...      4.2   4.2       3
# 4  http://www.imdb.com/title/tt6322922/ratings-age_2      6.3   6.5       9
#
#    1_votes  2_votes  3_votes   ...    1_pct  2_pct  3_pct  4_pct  5_pct  \
# 0      197        7        7   ...     49.0    1.7    1.7    0.7    1.7
# ...

# %%
pd.options.display.max_columns = None

# %%
df.sample(1).T
# Out:
#                                                    24078
# timestamp                     2017-08-09 11:50:05.915218
# respondents                                         1964
# category                                      IMDb users
# link         http://www.imdb.com/title/tt6322922/ratings
# average                                              5.1
# mean                                                 5.4
# median                                                 6
# 1_votes                                              845
# 2_votes                                               50
# 3_votes                                               28
# 4_votes                                               13
# 5_votes                                               23
# 6_votes                                               41
# 7_votes                                               58
# 8_votes                                               70
# ...

# %%
df.timestamp = pd.to_datetime(df.timestamp)

# %%
df.timestamp.describe()
# Out:
# count                          80053
# unique                         80053
# top       2017-07-24 23:00:02.760781
# freq                               1
# first     2017-07-17 12:28:32.785639
# last      2017-08-29 23:10:06.218251
# Name: timestamp, dtype: object

# %%
df.set_index('timestamp', inplace=True)

# %%
df['2017-08-29']
# Out:
#                             respondents            category  \
# timestamp
# 2017-08-29 00:00:02.248882         1682               Males
# 2017-08-29 00:00:02.499363          257             Females
# 2017-08-29 00:00:02.727204           15       Aged under 18
# 2017-08-29 00:00:03.024270           13      Males under 18
# 2017-08-29 00:00:03.248207            2    Females under 18
# 2017-08-29 00:00:03.441529          450          Aged 18-29
# 2017-08-29 00:00:03.636825          402    Males Aged 18-29
# 2017-08-29 00:00:03.839446           41  Females Aged 18-29
# 2017-08-29 00:00:04.030663          771          Aged 30-44
# 2017-08-29 00:00:04.225962          679    Males Aged 30-44
# 2017-08-29 00:00:04.539312           76  Females Aged 30-44
# 2017-08-29 00:00:04.776104          539            Aged 45+
# 2017-08-29 00:00:04.973766          421      Males Aged 45+
# 2017-08-29 00:00:05.176998          109    Females Aged 45+
# ...

# %%
df.category.value_counts()
# Out:
# Aged 30-44            4216
# Females Aged 45+      4216
# Females Aged 18-29    4216
# Top 1000 voters       4216
# Aged 18-29            4216
# Males Aged 18-29      4216
# Aged under 18         4216
# Males under 18        4216
# Non-US users          4216
# Females Aged 30-44    4216
# Females               4216
# Males Aged 30-44      4216
# Males Aged 45+        4216
# IMDb users            4216
# Aged 45+              4216
# US users              4216
# IMDb staff            4216
# Males                 4216
# Females under 18      4165
# Name: category, dtype: int64

# %%
df.link.value_counts()
# Out:
# http://www.imdb.com/title/tt6322922/ratings-female_age_2     4216
# http://www.imdb.com/title/tt6322922/ratings-top_1000         4216
# http://www.imdb.com/title/tt6322922/ratings-female_age_3     4216
# http://www.imdb.com/title/tt6322922/ratings-age_2            4216
# http://www.imdb.com/title/tt6322922/ratings                  4216
# http://www.imdb.com/title/tt6322922/ratings-male_age_2       4216
# http://www.imdb.com/title/tt6322922/ratings-imdb_staff       4216
# http://www.imdb.com/title/tt6322922/ratings-age_4            4216
# http://www.imdb.com/title/tt6322922/ratings-male_age_3       4216
# http://www.imdb.com/title/tt6322922/ratings-age_3            4216
# http://www.imdb.com/title/tt6322922/ratings-male_age_4       4216
# http://www.imdb.com/title/tt6322922/ratings-male             4216
# http://www.imdb.com/title/tt6322922/ratings-age_1            4216
# http://www.imdb.com/title/tt6322922/ratings-female           4216
# ...

# %%
df[df.category=='IMDb users']
# Out:
#                             respondents    category  \
# timestamp
# 2017-07-17 12:28:36.697246          678  IMDb users
# 2017-07-17 12:34:21.250099          678  IMDb users
# 2017-07-17 13:00:06.506688          678  IMDb users
# 2017-07-17 14:00:06.727742          679  IMDb users
# 2017-07-17 15:00:06.055125          679  IMDb users
# 2017-07-17 16:00:06.023053          679  IMDb users
# 2017-07-17 17:00:06.142993          679  IMDb users
# 2017-07-17 18:00:06.510891          680  IMDb users
# 2017-07-17 19:00:06.666467          680  IMDb users
# 2017-07-17 20:00:05.841494          681  IMDb users
# 2017-07-17 21:00:06.449770          681  IMDb users
# 2017-07-17 22:00:06.123852          682  IMDb users
# 2017-07-17 23:00:06.458620          682  IMDb users
# 2017-07-18 00:00:06.001629          682  IMDb users
# 2017-07-18 01:00:06.085490          682  IMDb users
# 2017-07-18 02:00:05.876108          685  IMDb users
# 2017-07-18 03:00:06.266496          685  IMDb users
# ...

# %%
lastday = df['2017-08-29']

# %%
lastday[lastday.category=='IMDb users'].respondents.plot();

# %%
final = df.tail(1)

# %%
columns = [column for column in lastday.columns if column[-4:] == '_pct']
final[columns]
# Out:
#                             1_pct  2_pct  3_pct  4_pct  5_pct  6_pct  7_pct  \
# timestamp
# 2017-08-29 23:10:06.218251   38.4    2.6    1.4    0.9    2.1    4.1    5.8
#
#                             8_pct  9_pct  10_pct
# timestamp
# 2017-08-29 23:10:06.218251    5.5    5.5    33.7

# %%
data = final[columns].T

# %%
data.index = range(1, 11)
data = data['2017-08-29 23:10:06.218251']
print(data.shape)
data
# Out:
# (10,)
# 1     38.4
# 2      2.6
# 3      1.4
# 4      0.9
# 5      2.1
# 6      4.1
# 7      5.8
# 8      5.5
# 9      5.5
# 10    33.7
# Name: 2017-08-29 23:10:06.218251, dtype: float64

# %%
# #ed723c from https://fivethirtyeight.com/features/al-gores-new-movie-exposes-the-big-flaw-in-online-movie-ratings/  google development tools color picker
colors = ['#333333'] * 10
colors[0] = '#ed723c' # #EC713B'
colors[-1] = '#ed723c' #'#EC713B'

colors
# Out:
# ['#ed723c',
#  '#333333',
#  '#333333',
#  '#333333',
#  '#333333',
#  '#333333',
#  '#333333',
#  '#333333',
#  '#333333',
#  '#ed723c']

# %%
import matplotlib as mpl
import matplotlib.font_manager as font_manager
import matplotlib.pyplot as plt
#!wget https://www.fontsquirrel.com/fonts/download/nimbus-mono  -P /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf
# https://www.fontsquirrel.com/fonts/download/courier-prime
font_manager._rebuild()
mpl.rc('font', family='Ariel')
font = font_manager.FontProperties(fname='/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf')
font
matplotlib.font_manager.findSystemFonts(fontpaths=['/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/', '/usr/share/fonts/truetype/'], fontext='ttf')
#matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['/usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf',
#  '/usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf',
# ...

# %%
plt.style.use(['fivethirtyeight'])


ax = data.plot.bar(color=colors, width=0.9, legend=False)
fig = ax.figure
fig.patch.set_facecolor('white')

fig.set_size_inches(5.46, 3.64)

ax.set(xlabel='Rating', 
       ylabel='Percent of total votes',
       yticks=range(0,41,10)
      )
       

# ax.text(x=-2, y=50, s="'An Inconvenient Sequel: Truth to Power' is divisive", 
#         fontsize=8, fontweight='heavy', fontproperties=font)
ax.text(x=-2, y=50, s="'An Inconvenient Sequel: Truth To Power' is divisive", 
        fontsize=14.5, fontweight='bold')

ax.text(x=-1.9, y=46, s="IMDb ratings for the film as of Aug. 29", fontsize=11.5, alpha=0.7)

ax.tick_params(labelrotation=0)
plt.axhline(y=40, color='black', linestyle='-', alpha=0.2)
ax.text(x=-0.9,y=39.4,color='black',alpha=0.5, s='%', fontsize=11);
ax.set_facecolor('white');
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['Ariel'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax = plt.subplot(121)
ax.set_facecolor('xkcd:white')
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(122)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(211)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(212)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(1, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ft = plt.subplots(1, 2, sharey=True, squeeze=False)
f = ft[0]
ax1, ax2 =ft[1][0]
ax1.plot(x1, y1, 'o-')
ax1.set_title('A tale of 2 subplots')
ax1.set_ylabel('Damped oscillation')

ax2.plot(x2, y2, '.-')
ax2.set_xlabel('time (s)')
ax2.set_ylabel('Undamped')
plt.show()

# %%
f?

# %%
import matplotlib
# !wget https://www.fontsquirrel.com/fonts/download/courier-prime  -P /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf
matplotlib.font_manager._rebuild()

# %%
210308/220978
